# %%
from __future__ import print_function, division

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Lambda, concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU,ReLU#,sigmoid 
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam 
from matplotlib.legend_handler import HandlerLine2D
from matplotlib.colors import LogNorm
import pylab as py
from keras import backend as K
import tensorflow as tf

import tensorflow as tf


import matplotlib
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
matplotlib.rc('text',usetex=True)
from matplotlib.legend_handler import HandlerLine2D
from matplotlib.colors import LogNorm
import pylab as py

import sys
path = '/w/jam-sciwork18/ccocuzza/fitpack'
sys.path.insert(0,path)
os.environ["FITPACK"] = path

path = '/w/jam-sciwork18/ccocuzza/analysis-hx'
sys.path.insert(0,path)

#--from tools
from tools.tools     import checkdir,save,load
import tools.config
from tools.config    import load_config, conf, options
from tools.inputmod  import INPUTMOD
from tools.randomstr import id_generator

#--from local
from analysis.corelib import core
from analysis.corelib import classifier

import numpy as np
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from IPython import display
from tools import checkdir, get_time,gen_code,send_command,lprint
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-jyldhpk7 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# <ipython-input-1-d77f0488c80f>:21: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
#--choose working directory to generate samples
wdir = '../../simul'

#--choose number of samples
N = 100

print('Generating new priors for %s'%wdir)

load_config('%s/input.py'%wdir)
istep=core.get_istep()

#cluster,colors,nc,cluster_order = classifier.get_clusters(wdir,istep,kc) 
#best_cluster=cluster_order[0]
  
#--get data
replicas=core.get_replicas(wdir)
step=conf['steps'][istep]
samples=[]
for i in range(len(replicas)):

    #if cluster[i]!=best_cluster: continue
    replica=replicas[i]
    order=replica['order'][istep]
    params=replica['params'][istep]
    samples.append(params)

samples=np.array(samples)

#--normalize samples
samples_mean = np.mean(samples, axis = 0)
samples_std  = np.std(samples, axis = 0)
norm_samples = (samples - samples_mean)/samples_std

pmin=np.amin(samples,axis=0)
pmax=np.amax(samples,axis=0)

# %%
norm_samples.shape

# %%
class LSGAN():
    def __init__(self):
        self.img_shape = (norm_samples.shape[1],)
        self.latent_dim = 100

        optimizer = Adam(0.000001, 0.5)
        #optimizer = Adam(0.00001, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='mse',
            optimizer=optimizer,
            metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # The generator takes noise as input and generated imgs
        z = Input(shape=(self.latent_dim,))
        img = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The valid takes generated images as input and determines validity
        valid = self.discriminator(img)

        # The combined model  (stacked generator and discriminator)
        # Trains generator to fool discriminator
        self.combined = Model(z, valid)
        # (!!!) Optimize w.r.t. MSE loss instead of crossentropy
        self.combined.compile(loss='mse', optimizer=optimizer)
              
            
    def linear_map(self, u):
        
        return pmin + (pmax-pmin)*u

    def build_generator(self):
        visible = Input(shape=(100,))

        hidden1 = Dense(256,  input_dim=self.latent_dim)(visible)
        LR = LeakyReLU(alpha=0.2)(hidden1)
        LR = BatchNormalization(momentum=0.8)(LR)
        
        hidden2 = Dense(512)(LR)
        LR = LeakyReLU(alpha=0.2)(hidden2)
        LR = BatchNormalization(momentum=0.8)(LR)

        hidden2 = Dense(512)(LR)
        LR = LeakyReLU(alpha=0.2)(hidden2)
        LR = BatchNormalization(momentum=0.8)(LR)
        
        hidden3 = Dense(1024)(LR)
        LR = LeakyReLU(alpha=0.2)(hidden3)
        LR = BatchNormalization(momentum=0.8)(LR)
        
        LR = Dense(norm_samples.shape[1],activation=tf.keras.activations.sigmoid)(LR)
        #LR  = ReLU(max_value=1.0)(LR)
        #LR  = sigmoid(LR)

        output = Lambda(self.linear_map)(LR)
        #outputmerge = concatenate([output, features])
        #generator = Model(inputs=visible, outputs=[outputmerge])
        generator = Model(inputs=visible, outputs=[output])
        generator.summary()
        img = generator(visible)
        return Model(visible, img)


    def build_discriminator(self):

        model = Sequential()

        model.add(Dense(512, input_shape=self.img_shape))
        model.add(LeakyReLU(alpha=0.2))
        # after the model converges I reduce the drop rate to 0.001
        model.add(Dropout(0.001))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.001))
        # (!!!) No softmax
        model.add(Dense(1))
        model.summary()

        img = Input(shape=self.img_shape)
        validity = model(img)

        return Model(img, validity)

    def train(self, epochs, batch_size=128, sample_interval=50):
                  
        #X_train = norm_samples
        X_train = samples

        print(X_train.shape)

        valid = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))

#         self.generator.load_weights('ls_generator.h5')
#         self.discriminator.load_weights('ls_discriminator.h5')
        
        dloss=[]
        gloss=[]
        accur=[]
        for epoch in range(epochs):

            # ---------------------
            #  Train Discriminator
            # ---------------------

            # Select a random batch of images
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]

            # Sample noise as generator input
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))

            # Generate a batch of new images
            gen_imgs = self.generator.predict(noise)

            # Train the discriminator
            d_loss_real = self.discriminator.train_on_batch(imgs, valid)
            d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)


            # ---------------------
            #  Train Generator
            # ---------------------

            g_loss = self.combined.train_on_batch(noise, valid)

            # Plot the progress
            #print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
            #loss_gen.append(g_loss[0])
            #loss_dis.append(d_loss[0])
            

            # If at save interval => save generated image samples
            dloss=np.append(dloss,d_loss[0])
            gloss=np.append(gloss,g_loss)
            accur=np.append(accur,d_loss[1])
            if epoch % sample_interval == 0:
                #print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
                self.generator.save_weights('generator_weights.h5')
                self.discriminator.save_weights('discrimiantor_weights.h5')
                
                print()
                I=np.linspace(1,len(gloss)+1,len(gloss))
                ax=py.subplot(111)
                ax.plot(I,gloss,label='gen-loss')
                ax.plot(I,dloss,label='dis-loss')
                ax.plot(I,accur,label='accur')
                #ax.set_ylim(0,1)
                #ax.set_yticklabels([])
                ax.semilogy()
                #ax.semilogx()
                ax.legend()
                
                display.display(py.gcf())
                display.clear_output(wait=True)
                py.close()

# %%
gan = LSGAN()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               102400
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 233,985
# Trainable params: 233,985
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               25856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_7 (Dense)              (None, 199)               203975
# _________________________________________________________________
# lambda (Lambda)              (None, 199)               0
# =================================================================
# Total params: 1,158,599
# Trainable params: 1,153,991
# Non-trainable params: 4,608
# _________________________________________________________________

# %%
gan.train(epochs=1000, batch_size=10, sample_interval=10)

# %%
code0="""import os,sys
import numpy as np
from mcgan import LSGAN
gan = LSGAN()
gan.train(epochs=100000, batch_size=10, sample_interval=10)
"""


code1="""#!/bin/csh
#SBATCH --account=jam
#SBATCH --nodes 1
#SBATCH --partition gpu
#SBATCH --time=10-00:00:00
#SBATCH --cpus-per-task 1
#SBATCH --gres=gpu:TitanRTX:1
#SBATCH --job-name=main
#SBATCH --output=./main.out
#SBATCH --error=./main.err
conda activate tf-gpu
python main.py
"""

gen_code(code0,'main.py')
gen_code(code1,'toslurm.sh')
print(send_command('sbatch toslurm.sh'))
# Out:
# Submitted batch job 45302700

# %%
print(send_command('squeue -n main'))
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           45302700       gpu     main    nsato  R       0:03      1 sciml1903

# %%
gloss=np.load('gloss.npy')
dloss=np.load('dloss.npy')
accur=np.load('accur.npy')

I=np.linspace(1,len(gloss)+1,len(gloss))
ax=py.subplot(111)
ax.plot(I,gloss,label='gen-loss')
ax.plot(I,dloss,label='dis-loss')
ax.plot(I,accur,label='accur')
ax.semilogy()
#ax.semilogx()
ax.legend()

# %% [markdown]
# ## results

# %%
gan.generator.load_weights('generator_weights.h5')

# %%
noise = np.random.normal(0, 1, (samples.shape[0], 100))
results = gan.generator.predict(noise, batch_size=10)
#results = results*samples_std+samples_mean

# %%
for i in range(samples.shape[1]):
    nrows,ncols=1,1
    fig = py.figure(figsize=(ncols*7,nrows*6))
    ax=py.subplot(nrows,ncols,1)
    ax.hist(samples[:,i],color='y');
    ax.hist(results[:,i],histtype='step',color='b');
# Out:
# <ipython-input-8-7e784144214c>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = py.figure(figsize=(ncols*7,nrows*6))

# %%
nrows,ncols=1,2
fig = py.figure(figsize=(ncols*7,nrows*6))
IDX=range(samples.shape[1])
Y1,dY1=[],[]
Y2,dY2=[],[]

norm_results= (results - samples_mean)/samples_std

for idx in IDX:
    Y1.append(np.mean(norm_samples[:,idx]))
    dY1.append(np.std(norm_samples[:,idx]))
    Y2.append(np.mean(norm_results[:,idx]))
    dY2.append(np.std(norm_results[:,idx]))
ax=py.subplot(nrows,ncols,1)
ax.errorbar(IDX,Y1,dY1,fmt='r.');    
ax=py.subplot(nrows,ncols,2)
ax.errorbar(IDX,Y2,dY2,fmt='r.');    
#ax.axhline( 1,color='k',ls=':')    
#ax.axhline(-1,color='k',ls=':')

# %%
optimized_priors=results#*samples_std+samples_mean
#np.save('gan_priors.npy',optimized_priors)

# %%
#--save samples
replica=replicas[0] #--template replica
checkdir('%s/msr-opt-priors'%wdir)
for i in range(N):
    replica['params'][istep]=optimized_priors[i]
    fname='%s/msr-opt-priors/%s.msr'%(wdir,id_generator(12))
    save(replica,fname)

print 
print('Saving new priors to %s/msr-opt-priors'%wdir)
# Out:
# '/w/jam-sciwork18/nsato/codes/pargan'
